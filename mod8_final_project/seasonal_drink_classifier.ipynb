# %% [markdown]
# # Seasonal Drink Classifier: Coffee Shop PCA + SVM
#
# Can you teach a computer which **season** a drink belongs to using only flavor features?
#
# Seasons:
# - 🌸 spring
# - ☀️ summer
# - 🍂 fall
# - ❄️ winter
#
# You will mainly code two pieces:
# 1. PCA to visualize drinks in 2D flavor space
# 2. SVM to classify drinks into seasons
#
# Everything else (data generation and scaling) is already done for you.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.decomposition import PCA
from sklearn.svm import SVC
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
import warnings
warnings.filterwarnings('ignore')

plt.rcParams['figure.figsize'] = (10, 5)
sns.set(style="whitegrid")

# %% [markdown]
# ## Dataset (PROVIDED)
#
# Each drink has these features (0–10 scale):
# - `spice`
# - `temperature` (0 = iced, 10 = very hot)
# - `flavor_notes` (richness / sweetness)
# - `fruitiness`
# - `color_tone` (0 = very light, 10 = very dark)
# - `foaminess`
#
# Label: `season` ∈ {spring, summer, fall, winter}
#
# Run the code below to generate the dataset.

# %%
np.random.seed(42)

seasons = ["spring", "summer", "fall", "winter"]

def generate_season_drinks(season, n):
    base = {
        "spring": dict(spice=3, temperature=6, flavor=6, fruit=7, color=3, foam=4),
        "summer": dict(spice=1, temperature=2, flavor=5, fruit=8, color=2, foam=2),
        "fall":   dict(spice=8, temperature=8, flavor=8, fruit=3, color=8, foam=7),
        "winter": dict(spice=6, temperature=9, flavor=9, fruit=2, color=9, foam=8)
    }
    params = base[season]

    def clip_norm(mean, std, size):
        return np.clip(np.random.normal(mean, std, size), 0, 10)

    return pd.DataFrame({
        "spice":        clip_norm(params["spice"], 1.2, n),
        "temperature":  clip_norm(params["temperature"], 1.2, n),
        "flavor_notes": clip_norm(params["flavor"], 1.2, n),
        "fruitiness":   clip_norm(params["fruit"], 1.2, n),
        "color_tone":   clip_norm(params["color"], 1.2, n),
        "foaminess":    clip_norm(params["foam"], 1.2, n),
        "season":       [season] * n
    })

drinks = pd.concat([
    generate_season_drinks(s, 20) for s in seasons
], ignore_index=True)

print(drinks.head())
print("\nDataset size:", drinks.shape)
print("\nSeason counts:\n", drinks["season"].value_counts())
print(f"\n✓ Loaded {len(drinks)} drinks across {drinks['season'].nunique()} seasons\n")
# Out:
#       spice  temperature  flavor_notes  fruitiness  color_tone  foaminess  \
# 0  3.596057     7.758779      6.886160    6.424991    2.736394   2.301555
# 1  2.834083     5.729068      6.205642    6.777209    3.428535   3.495226
# 2  3.777226     6.081034      5.861222    5.672398    4.773473   3.588743
# 3  4.827636     4.290302      5.638676    5.564552    2.378076   3.037267
# 4  2.719016     5.346741      4.225774    7.975031    2.029808   3.806457
#
#    season
# 0  spring
# 1  spring
# 2  spring
# 3  spring
# 4  spring
#
# Dataset size: (80, 7)
#
# Season counts:
#  season
# spring    20
# summer    20
# fall      20
# winter    20
# Name: count, dtype: int64
#
# ✓ Loaded 80 drinks across 4 seasons

# %% [markdown]
# ### 🧠 Warm-Up Questions
#
# Answer in your notebook or discuss with a partner:
# 1. Which features do you think matter most for telling seasons apart? Why?
# 2. Which two seasons do you think will be the hardest to separate? Why?
# 3. If you worked at a cafe, how might you use a "season predictor" like this in real life?

# %% [markdown]
# ### A:
#
# 1. I think temperature is the most important feature for telling the seaons apart. This is because it has the best 'relationship' with seasons specifically when compared to the others. Just by looking at the temperature, it is possible to tell what season the drink is most likely to be drank in.
# 2. I think spring and fall will be the hardest to seperate. Unlike summer or winter, there are no extremes in any of these seasons and there is moderate weather throughout them. Furthermore, the conditions and the temperature is similar throughout.
# 3. If you are working in a cafe, you can use this to predict what drinks people will get, which helps predict inventory, sales, and many other important metrics.

# %% [markdown]
# ## PART 1: Prepare and Scale Features (Done For You)
#
# We will:
# - Select numeric feature columns
# - Scale them so all features are on a similar range
#
# This is already implemented. Just run the cell.

# %%
features = [
    "spice", "temperature", "flavor_notes",
    "fruitiness", "color_tone", "foaminess"
]

X = drinks[features].values
y = drinks["season"].values

scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

print("✓ Data scaled\n")
print(f"Original data shape: {X.shape}")
print(f"Scaled data shape: {X_scaled.shape}\n")
# Out:
# ✓ Data scaled
#
# Original data shape: (80, 6)
# Scaled data shape: (80, 6)

# %% [markdown]
# ### Checkpoint Questions
# 1. Why might it be a bad idea to run PCA and SVM on **unscaled** flavor features?
# 2. Which features do you expect to have the biggest impact on whether a drink feels "winter" vs "summer"?

# %% [markdown]
# ### A:
# YOUR ANSWERS HERE
#
# 1. Running PCA and SVM on unscaled features would be bad because it would give a preference to the features who have a larger value. For example, if something like flavor notes is usually a number around 3, but temperature can go all the way up to 10, then it would give a prefernce to the temperature since it simply has the bigger number. Also, some variables probably have a bigger weight than others, such as temperature vs. foaminess.
# 2. I think temperature will have the biggest impact on whether the drink has a winter or summer feel. For example, people are more likely to have hot chocolate in the winter and iced drinks in the summer. Also, I checeked Google Trends which confirmed that there is a massive spike every year in hot chocolate during the colder months such as November and December. Spice is also a differentiator between the two since spiced drinks are more likely to be drank during the winter.

# %% [markdown]
# ----

# %% [markdown]
# ## PART 2: Using PCA to Visualize Seasonal Flavor Space
#
# Now **you** implement PCA.
#
# Goals:
# 1. Fit PCA with 2 components on `X_scaled`
# 2. Transform the data into `X_pca`
# 3. Plot PCA Component 1 vs Component 2, with points colored by season
#
# Think about: do certain seasons form clear clusters?

# %%
pca = PCA(n_components=2)
X_pca = pca.fit_transform(X_scaled)

print("PCA shape:", None if X_pca is None else X_pca.shape)
print("Explained variance ratio:", None if pca is None else pca.explained_variance_ratio_)
# Out:
# PCA shape: (80, 2)
# Explained variance ratio: [0.80167536 0.05957967]

# %%
plt.figure(figsize=(8, 5))

seasons_unique = drinks["season"].unique()
palette = {
    "spring": "#77dd77",
    "summer": "#ffb347",
    "fall":   "#c23b22",
    "winter": "#779ecb"
}

for s in seasons_unique:
    mask = (y == s)
    plt.scatter(
        X_pca[mask, 0],
        X_pca[mask, 1]  ,
        label=s.capitalize(),
        alpha=0.8,
        s=60,
        c=palette[s]
    )

plt.xlabel("PCA Component 1")
plt.ylabel("PCA Component 2")
plt.title("Seasonal Drinks in PCA Flavor Space")
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# ### PCA Reflection
# Answer in the markdown cell below:
#
# 1. Which seasons look most **separated** in your PCA plot? Which seasons overlap?
# 2. SKIP #2
# 3. If you added a new feature like `sweetness`, how do you think that might change the PCA picture?

# %% [markdown]
# ### A:
# YOUR ANSWERS HERE
#
# 1. Fall and winter are clearly seperated from spring and summer. Fall and winter have a big overlap in both components. However, spring and summer are pretty close to each other but there is less overlap than the fall and winter data. It would be possible to identify spring vs summer but it would be a lot harder to do this with fall and winter.
# 3. If we added sweetness, the data would look different, but it is hard to identify how the data would change.

# %% [markdown]
# ----

# %% [markdown]
# ## PART 3: SVM – Build a Season Classifier
#
# Now you will train an **SVM classifier** using the scaled features.
#
# Steps:
# 1. Split `X_scaled` and `y` into train and test sets
# 2. Create an SVM with an RBF kernel
# 3. Fit the model on the training data
# 4. Predict on the test data
# 5. Print a classification report
#
# Try to think: will the model confuse any seasons? Which ones?

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X_scaled,
    y,
    test_size=0.3,
    random_state=0,
    stratify=None
)

svm_clf = SVC(kernel="rbf", gamma="scale", C=1.0, random_state=0)
svm_clf.fit(X_train, y_train)

y_pred = svm_clf.predict(X_test)

print("Classification report:\n")
print(classification_report(y_test, y_pred))
# Out:
# Classification report:
#
#               precision    recall  f1-score   support
#
#         fall       0.75      0.86      0.80         7
#       spring       1.00      1.00      1.00         3
#       summer       1.00      1.00      1.00         6
#       winter       0.86      0.75      0.80         8
#
#     accuracy                           0.88        24
#    macro avg       0.90      0.90      0.90        24
# weighted avg       0.88      0.88      0.88        24

# %% [markdown]
# ### SVM Evaluation Questions
#
# 1. Look at the **precision** and **recall** for each season.
#    - Which season is easiest for the model?
#    - Which is hardest?
# 2. Do your PCA clusters match what the SVM report says? For example, if two seasons overlapped in PCA, does the model confuse them?
# 3. If you could collect **real cafe data**, what extra features would you add to help the model (examples: price, milk type, size, toppings)?

# %% [markdown]
# ### A:
# YOUR ANSWERS HERE
#
# 1. The easiest seasons were spring and summer since the precisiona and recall were both 1.00 for these. Whenever the model predicted spring it was correct, and it found all of the actual spring drinks correctly, and this is the same in summer as well. The hardest seasons for the model were fall and winter.
# 2. Yes, the PCA clusters match the SVM report. Since spring and summer had perfect scores, this means they formed clear, separate clusters in the PCA graph. Winter and fall were harder to classify, so their points overlapped in the SVM space, which we can see on the graph above.
# 3. I would add size, time of day, price, and milk type.

# %% [markdown]
# ----

# %% [markdown]
# ## PART 4: Try Your Own Drinks ☕✨
#
# Create your own drinks and see what season the model predicts.
#
# Think of 2–4 fun drink names and decide their flavor numbers:
# - Example names:
#   - "Caramel Cloud Dream"
#   - "Iced Strawberry Matcha Glow"
#   - "Mocha Midnight Storm"
#
# Then run the code below after your SVM is trained.
#
# Before you run it, **guess** the season for each drink yourself. Then compare with the model.

# %%
new_drinks = pd.DataFrame([
    {"name": "Brain Freeze", "spice": 0, "temperature": 0, "flavor_notes": 9,
     "fruitiness": 2, "color_tone": 4, "foaminess": 3},
    {"name": "Iced Strawberry Matcha Glow", "spice": 2, "temperature": 3, "flavor_notes": 6,
     "fruitiness": 9, "color_tone": 3, "foaminess": 4}
])

feature_cols = ["spice", "temperature", "flavor_notes", "fruitiness", "color_tone", "foaminess"]

X_new = new_drinks[feature_cols].values
X_new_scaled = scaler.transform(X_new)
pred_seasons = svm_clf.predict(X_new_scaled)

new_drinks["predicted_season"] = pred_seasons
print(new_drinks[["name", "predicted_season"]])
# Out:
#                           name predicted_season
# 0                 Brain Freeze           summer
# 1  Iced Strawberry Matcha Glow           summer

# %% [markdown]
# ### Final Reflection
#
# 1. Did the model agree with your own guesses for your custom drinks? If not, what would you change about the flavor numbers to "convince" the model?
# 2. Do you think season labels for drinks are **objective** (based on features) or **subjective** (based on people’s feelings)? How does that affect modeling?
# 3. Imagine this model is part of a cafe app that recommends drinks based on the weather. What other data (outside of the drink itself) would you include?

# %% [markdown]
# ### A:
# YOUR ANSWERS HERE
#
# 1. Yes, the moodel agreed with all of my own guesses for the custom drinks. It correctly classifid my drink Brain Freeze as one that would be had in summer.
# 2. I think that they are subjective but they are easy to predict. Anyone can have hot chocolate during summer,. but it is less likely since the body is already very hot and would like something refreshing.
# 3. I would take user feedback as well along with price and the time of the day. At 2 pm in the middle fo July, it is going to be different than the preferred drink at 10 pm.

# %% [markdown]
# ### Key Takeaway 🔑
# PCA helps us **see** patterns in high-dimensional flavor data, and SVM learns **boundaries** between seasons in that space. Together, they turn vibes like "cozy fall latte" into patterns a computer can understand.
